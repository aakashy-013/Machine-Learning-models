# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
data = pd.read_csv('Files/Raw_Skills_Dataset.csv')

# %%
data
# Out:
#                                             RAW DATA
# 0                                           What ifs
# 1                                          seniority
# 2                                        familiarity
# 3                                    functionalities
# 4                                            Lambdas
# ...                                              ...
# 34111                                    negotiation
# 34112                                      deadlines
# 34113  Self-motivated, enthusiastic and strong drive
# 34114                                    negotiation
# 34115                                      deadlines
#
# [34116 rows x 1 columns]

# %%
data.value_counts()
# Out:
# RAW DATA
# Python                          272
# AWS                             239
# JavaScript                      220
# Kubernetes                      180
# Familiarity                     172
#                                ...
# SDLC compliance                   1
# SDRG                              1
# SDTM specifications document      1
# SEITs                             1
# 🏗                                 1
# Length: 15677, dtype: int64

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ## 1. Removing stopwords

# %%
#removing stopwords
sent=[]
s=""
for i in range(len(data)):
    words = word_tokenize(str(data.iloc[i].values[0]))
    s=""
    for j in words:
        if j.lower() not in stop_words:
            s=s+" "+j
    sent.append(s.strip())

# %%
sent
# Out:
# ['ifs',
#  'seniority',
#  'familiarity',
#  'functionalities',
#  'Lambdas',
#  'Java Streams',
#  'Object Oriented analysis',
#  'Relational Databases',
#  'SQL',
#  'ORM',
#  'JPA2',
#  'Hibernate',
#  'MyBatis',
#  'Hibernate',
#  'code versioning tools',
#  'Git .. Familiarity',
#  'Maven',
#  'Gradle .. Familiarity',
#  'continuous integration',
#  'continuous delivery development processes',
#  'jenkins',
#  'bamboo',
#  'Familiarity',
#  'frameworks',
#  'transformations',
#  'analytical reporting',
#  'conceptual data models',
#  'standard naming conventions',
#  'coding practices',
#  'consistency',
#  'optimized solutions',
#  'methodologies',
#  'high throughput data access services',
#  'analyze/profile data',
#  'conceptual , logical & physical data model designs',
#  'reporting analytics solutions',
#  'physical databases',
#  'variances',
#  'discrepancies',
#  'phases',
#  'integrations',
#  'Demonstrable experience',
#  'logical physical data models',
#  'interpersonal skills',
#  'modern enterprise data architectures',
#  'data toolsets',
#  'e.g . : data warehouse',
#  'data marts',
#  'modeling tools',
#  'profiling tools',
#  'Bachelor Master degree',
#  'STEM majors',
#  'Strong algorithms',
#  'coding background',
#  'either Java',
#  'Python',
#  'Scala programming experience',
#  'Exceptional proficiency',
#  'SQL',
#  'following distributed technologies',
#  'Relational Stores',
#  'i.e . Postgres',
#  'MySQL',
#  'Oracle',
#  'NoSQL Stores',
#  '( i.e . Big Query',
#  'Clickhouse',
#  'Distributed Processing Engines',
#  'i.e . Apache Spark',
#  'Apache Flink',
#  'Celery',
#  'Distributed Queues',
#  'i.e . Apache Kafka',
#  'AWS Kinesis',
#  'GCP PusSub',
#  'standard methodologies',
#  'GCP',
#  'Azure',
#  'AWS',
#  'similar cloud platform technologies',
#  'persuasion',
#  'experience building cloud environments',
#  'Excellent Unix/Linux experience programming experience',
#  'scripting',
#  'python , shell',
#  'IPC mechanisms',
#  'TCP/IP',
#  'Kafka',
#  'zmq',
#  'grpc',
#  'microservice architecture',
#  'orchestration',
#  'docker',
#  'kubernetes',
#  'cloud environments',
#  'etcd',
#  'service meshes',
#  'envoy',
#  'vault',
#  'API gateways',
#  'load balancers',
#  'databases',
#  'consistency',
#  'sql/nosql',
#  'columnar databases',
#  'distributed consensus',
#  'CAP Theorem',
#  'RAFT',
#  'map-reduce , reliable multicast',
#  'Paxos',
#  'CI/CD',
#  'Github',
#  'Makefiles',
#  'Microservices',
#  'AWS',
#  'GCPNode.js',
#  'REST APIs servicesExperience writing tools',
#  'Ruby',
#  'PerlExperience',
#  'Bazel',
#  'toolingScala programming experienceKnowledge',
#  'HTTP 2/websocket',
#  'binary protocolsExperience',
#  'Redis',
#  'experience building cloud environments',
#  'Excellent Unix/Linux experience programming experience',
#  'scripting',
#  'python , shell',
#  'IPC mechanisms',
#  'TCP/IP',
#  'Kafka',
#  'zmq',
#  'grpc',
#  'microservice architecture',
#  'orchestration',
#  'docker',
#  'kubernetes',
#  'cloud environments',
#  'etcd',
#  'service meshes',
#  'envoy',
#  'vault',
#  'API gateways',
#  'load balancers',
#  'databases',
#  'consistency',
#  'sql/nosql',
#  'columnar databases',
#  'distributed consensus',
#  'CAP Theorem',
#  'RAFT',
#  'map-reduce , reliable multicast',
#  'Paxos',
#  'CI/CD',
#  'Github',
#  'Makefiles',
#  'Microservices',
#  'AWS',
#  'GCPNode.js',
#  'REST APIs servicesExperience writing tools',
#  'Ruby',
#  'PerlExperience',
#  'Bazel',
#  'toolingScala programming experienceKnowledge',
#  'HTTP 2/websocket',
#  'binary protocolsExperience',
#  'Redis',
#  'Web UIExperience',
#  'JavaScript',
#  'HTML',
#  'CSS',
#  'algorithms',
#  'standard ( W3C ) Web UI APIs',
#  'following types frameworks/libraries/languages',
#  'Angular',
#  'Meteor',
#  'Ember',
#  'Knockout',
#  'UI Component libraries',
#  'Vue',
#  'Bootstrap',
#  'ES6',
#  'TypeScript',
#  'Dependency injection patterns',
#  'Async Module Definition',
#  'AMD , requireJS',
#  'commonJS',
#  'Stylesheet languages',
#  'SASS',
#  'Redux',
#  'Reactive Programming',
#  'RxJS',
#  'JavaStrong programming skills',
#  'lambdas',
#  'optionals',
#  'Guice knowledge',
#  'Protobuf knowledge',
#  ': Familiarity',
#  'consuming service oriented architecture layers',
#  'APIs',
#  'highly scalable applications',
#  'Web UI : Deep understanding',
#  'JSON',
#  'JavaScript Design',
#  'Architectural Patterns',
#  'Proficiency',
#  'Maven',
#  ', Eclipse/NetBeans/IntelliJ',
#  'Spring/Guice',
#  'JPA/Hibernate',
#  'JavaExperience',
#  'highly distributed scalable systems',
#  'Containers knowledge',
#  'Multi-threaded concepts',
#  'latency',
#  'heap',
#  'profiling',
#  'distributed troubleshooting',
#  'NoSQL',
#  'MongoDB',
#  'Cassandra',
#  'Redis',
#  'Java Application Servers',
#  'Oracle WebLogic',
#  'JBoss',
#  'Tomcat',
#  'frameworks',
#  'Jasmine',
#  'Karma',
#  'Protractor',
#  'Junit',
#  'Cross-browser techniques',
#  'Chrome Dev Tools',
#  'Responsive design implementation',
#  'Browser performance auditing',
#  'tuning',
#  'distributed code repositories',
#  '( Git , Perforce',
#  'Scrum / Kanban',
#  'Guice',
#  'GRPC',
#  '-',
#  '-',
#  '/BTech/BS',
#  'Excellent analytical problem-solving skills',
#  'Proven-deep-expertise',
#  'Python programming',
#  'Python',
#  'frameworks',
#  'Django',
#  'Flask',
#  'APIs',
#  'RDBMS strong SQL knowledge',
#  'Unix / Linux command line',
#  'Object-oriented concepts',
#  'Familiarity',
#  'UI frameworks',
#  'Redux',
#  'usability design',
#  'Hadoop / Hive / Presto',
#  'ML/AI frameworks',
#  'TensorFlow',
#  'H20',
#  'noSQL databases',
#  'docker container platforms',
#  'Mesos',
#  'Kubernetes',
#  'Application benchmarking',
#  'optimization',
#  'Building user interface applications',
#  'analytical devices',
#  'measurement control algorithms',
#  'UI Applications',
#  'analytical , medical , automotive devices',
#  'Proficiency',
#  'programming user interfaces',
#  'Qt Framework',
#  'QML',
#  'Qt/C++',
#  'regulated markets',
#  'embedded Linux-Systems',
#  'RasPi',
#  'BeagleBone',
#  'SQL',
#  'IP-based network protocols',
#  'Linux-Yocto distribution',
#  'Myntra ’ new product platforms',
#  'mentor',
#  'Architects',
#  'DevOps engineers',
#  'architectural design best practices',
#  'deployment',
#  'scaling',
#  'availability characteristics',
#  'long-term architectural direction',
#  'platforms/ reusable components',
#  'nimble delivery process',
#  'reliability',
#  'extensibility',
#  'deliverables',
#  'next generation extensible web',
#  'mobile fashion commerce platforms',
#  'security protocols',
#  'customisation',
#  'continuous scaling',
#  'internationalization',
#  'extensions',
#  'architectural governance',
#  'directional paths',
#  'new technology stacks',
#  'multiple technology domains',
#  'Myntra',
#  'external technical forums',
#  'business stakeholders',
#  '-',
#  'term , long-term roadmaps',
#  'excellent abstraction',
#  'coding',
#  'startup/e-commerce ecosystem',
#  'high growth & matrix environment',
#  'efficient proficient problem-solver',
#  'business technical perspectives',
#  'workable solutions',
#  'leading product development end-end ( portfolio',
#  '-',
#  'architectures',
#  'multi-million sessions/transactions',
#  'rdbms & NoSQL stores',
#  'massively large scale distributed internet systems',
#  'Java/GO',
#  'multi-threading performance oriented programming',
#  'highly scalable products',
#  'reliability',
#  'queues',
#  'frameworks',
#  'object-oriented programming',
#  'concurrency',
#  'fundamentals',
#  'Developing user-facing web applications',
#  'reusable , modular code',
#  'Bachelor',
#  'Backend services',
#  'React JS',
#  'JS/TypeScript',
#  'Redux',
#  'Webpack bundling',
#  'Dev tools',
#  'markup languages',
#  'HTML5',
#  'CSS3',
#  'CSS',
#  'pre-processing platforms',
#  'SASS',
#  'SCSS',
#  'Mysql',
#  'Postgres',
#  'Data modeling skills',
#  'testing frameworks',
#  'code versioning tool - Git',
#  'phases',
#  'deployment',
#  'standardized methodology',
#  'Detail Design phases',
#  'outputs',
#  'architectural development',
#  'modifications',
#  'specifications',
#  'congruence',
#  'compatibility',
#  'interdependent technologies',
#  'computing related technology programs',
#  'Minimum 1 year Java design development experience',
#  'Spring Hibernate based solutions',
#  'technical expertise',
#  'statistical programming tasks',
#  'technical expertise',
#  'Statistical Programming department',
#  'High-Quality Deliverables',
#  'complex assigned tasks',
#  'appropriate validation requirements',
#  'SOPs',
#  'Checks programming logs',
#  'cleanliness',
#  'Inputs',
#  'programming specifications datasets',
#  'datasets',
#  'Handles',
#  'dataset derivations',
#  'Programs TLFs',
#  'biostatistical tools',
#  'questions specification',
#  'consistency',
#  'lead programmer',
#  'Biostatistical Team Lead',
#  'supervisor',
#  'project specific macros',
#  'SOPs',
#  'timely progress updates',
#  'EAC',
#  'documents timelines',
#  'BIOSETUP',
#  'integrated databases',
#  'project macros',
#  'SAP',
#  'shells',
#  'programming specifications',
#  'safety outputs',
#  'Shares accountability',
#  'contract budget assumptions',
#  'rework',
#  'mentors junior staff',
#  '( QC ) review',
#  'define xmls',
#  'ADaM reviewers guide',
#  'SDRG',
#  'ADRG',
#  'lead programmer role',
#  'proactive approach',
#  'efficiencies',
#  'protocols',
#  'RFPs',
#  'bid defenses',
#  'operational topics',
#  "Master 's Degree Computer science",
#  "Bachelor 's Degree Computer science",
#  'CDISC/ADaM/SDTM',
#  'Base SAS',
#  'SAS/STAT',
#  'SAS Macro Language',
#  'Good organizational , interpersonal , leadership communication skills',
#  'coworkers',
#  'talented , enthusiastic , detail-oriented Data Engineer',
#  'agile way',
#  'analysis data modeling',
#  'deployment',
#  'big data pipelines',
#  'Data Analytics team',
#  'Coda',
#  'data pipelines',
#  'analytical techniques',
#  'insights',
#  'ETL',
#  'big data pipelines',
#  'AWS technologies',
#  'Redshift',
#  'S3',
#  'EMR',
#  'EC2',
#  'DynamoDB',
#  'Kinesis Firehose',
#  'Lambda',
#  'ML teams',
#  'new behavioural events',
#  'pipelines',
#  'datasets',
#  'offline analytics capabilities',
#  'Tableau',
#  'real time dash boarding capabilities',
#  'Bachelor ’ degree',
#  'similar quantitative field',
#  'Redshift',
#  'another columnar store DW',
#  'cloud solutions / AWS / Azure / Google cloud',
#  'data visualization',
#  'Hadoop/MapReduce/AWS',
#  'EMR',
#  'Spark/Scala/PySpark/ Apache Kafka / Kinesis Streams / AWS Glue',
#  'reporting/analytics platforms',
#  'Experience building flexible data APIs',
#  'business Preferred Qualifications',
#  'data/software developer/scientist',
#  'predictive analytics/decision models',
#  'data mining libraries',
#  'algorithm design',
#  'problem solving',
#  'Agile Development',
#  'Collaborative Filtering',
#  'iOS mobile application',
#  'high visibility',
#  'fundamentals',
#  'algorithms',
#  'relevant SWE experience',
#  'iOS apps',
#  'Preferably , apps',
#  'AppStore',
#  'XCode .. Experience',
#  '( MVVM',
#  'Proficiency',
#  'Multi-threading performance & memory optimization',
#  'RESTful APIs',
#  'Proficient understanding',
#  'code versioning tools',
#  'Git',
#  'individual projects priorities',
#  'deadlines',
#  'deliverables',
#  'technical expertise',
#  'bottlenecks',
#  'software stack',
#  'Rubrik Software Engineers',
#  'self-starters',
#  'limitless drive',
#  'Bachelor',
#  'Master ’ degree',
#  'Proficiency',
#  'Scala',
#  'Python',
#  'Google Cloud Platform/AWS/Azure',
#  'Unix/Linux environments',
#  'Windows environments',
#  'networking',
#  'hypervisors',
#  'databases',
#  'AWS',
#  'Azure',
#  'GCP',
#  'databases',
#  'AWS',
#  'granular file recovery',
#  'Kubernetes Service',
#  'AWS',
#  'elastic compute',
#  'technical specifications',
#  'concise effective manner',
#  'agile activities',
#  'sprint planning',
#  'thorough knowledge',
#  'key architectural decisions',
#  'design considerations',
#  'detailed RCA',
#  'Bachelor',
#  'master ’ degree',
#  'object-oriented languages',
#  'developing Microservices',
#  'RESTful services',
#  'SOA development experience',
#  'preferably AWS',
#  'ORM',
#  'Entity Framework',
#  'Nhibernate',
#  'Strong TDD approach',
#  'Nunit',
#  'xUnit',
#  'frameworks',
#  'OOP SOLID design principles',
#  'public cloud providers',
#  'Azure',
#  'modern java script frameworks',
#  'Highly efficient data persistent design techniques',
#  'data retrieval performance',
#  '( queries',
#  'designs/queries',
#  'Proficient experience',
#  'relational databases',
#  'Microsoft SQL Server/Postgres',
#  'non-relational DBs',
#  'MongoDB',
#  'concurrency',
#  'parallel work streams',
#  'Agile practices',
#  'Debugging/Troubleshooting functional technical issues',
#  'Performance/Optimization techniques',
#  'proactively codes',
#  'Excellent analytical , quantitative , problem-solving abilities',
#  'algorithms',
#  'minimal oversight',
#  'multiple concurrent priorities',
#  'fast-paced environment',
#  'Strong interpersonal',
#  'Utilizes knowledge',
#  'Xamarin',
#  'Transforms business requirements',
#  'technical specifications',
#  'DevOps model',
#  'debug',
#  'Generating testing test cases',
#  'uniformity',
#  'Architects',
#  'various prototypes',
#  'Bachelor ’ degree',
#  'LINQ',
#  'Rest APIs',
#  'Xamarin Forms',
#  'Xamarin Native development',
#  '( Xamarin iOS , Xamarin Droid',
#  'Xamarin Studio',
#  'Xamarin',
#  'Apple iOS Android platforms',
#  'Xamarin Apps',
#  'UWP',
#  'XAML',
#  'e.g . Azure integrations',
#  'Azure Active Directory',
#  'Notifications',
#  'HockeyApp/Visual Studio App Center',
#  'Continuous Integration',
#  'CI',
#  'DevOps',
#  'Automation Testing',
#  'Xamarin',
#  'Xamarin Profiler',
#  'Various code repositories',
#  'Git',
#  'TFS',
#  'MVVM Architecture',
#  'Agile methodology',
#  'VSTS',
#  'Overall Cross Platform app development ecosystem',
#  'lifecycle',
#  'roadmaps',
#  'Portable Class Library',
#  'PCL',
#  'SQLite',
#  'cross-platform UX design',
#  'Xamarin Binding',
#  'SAP HANA REST API Integration',
#  'Xamarin',
#  'Xamarin Forms',
#  'Core Java',
#  'Swift / XCode',
#  'fast-paced & complex environment',
#  'self-motivated work ethic',
#  'urgency',
#  'Willingness',
#  'relevant SOPs',
#  'servicesIntegrate Highspot',
#  'external APIs',
#  'CRM',
#  'CMS',
#  'clean , reusable , supportable , well-tested RESTful APIs',
#  'Highspot ’ external API',
#  'Highspot ’ Salesforce integrations',
#  'functionality',
#  '-',
#  'UX',
#  'maintainable testable code',
#  'internal external technical documentation',
#  'Proficiency',
#  'APIs',
#  'data formats',
#  'data transformations',
#  'scalable internet software',
#  'object-oriented functional design patterns',
#  'Highspot ’ Infrastructure Platform crew',
#  'feature crews',
#  'DevOps',
#  'frameworks',
#  'Highspot',
#  'highly-scalable reliable infrastructure',
#  'engineering crews',
#  'highly-availability distributed services',
#  'observability',
#  'shared frameworks',
#  'caches',
#  'indexes',
#  'frameworks',
#  '-',
#  'Highspot ’ feature engineering crews',
#  'well DevOps/Site-Reliability',
#  'maintainable testable code',
#  'internal external technical documentation',
#  'Proficiency',
#  'cloud computing',
#  'containerization',
#  'Kubernetes',
#  'scalable internet software',
#  'object-oriented functional design patterns',
#  'Clojure',
#  'Angular',
#  'Vue',
#  '.. APIs',
#  'emerging frameworks',
#  'architectural patterns',
#  'Node',
#  'Typescript',
#  'industry leading cloud providers',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Operational efficiencies',
#  'modern ecosystems',
#  'automated build deployment pipelines',
#  'Collaborative build practices',
#  'collaborative product engineering team',
#  'velocity multiplier',
#  'refinement',
#  'entire software stack',
#  'API',
#  'UI components',
#  'norms',
#  'software development capabilities',
#  'agile techniques',
#  'oversight',
#  'project roadmap',
#  'emerging technologies',
#  'frameworks',
#  'cloud-based ecosystems',
#  'proven validation techniques',
#  'scripts',
#  'routines',
#  'production environments',
#  'Angular',
#  'Vue',
#  '.. APIs',
#  'emerging frameworks',
#  'architectural patterns',
#  'Node',
#  'Typescript',
#  'industry leading cloud providers',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Operational efficiencies',
#  'modern ecosystems',
#  'automated build deployment pipelines',
#  'Collaborative build practices',
#  'collaborative product engineering team',
#  'refinement',
#  'talented software engineers',
#  'architects',
#  'entire software stack',
#  'API',
#  'UI components',
#  'norms',
#  'emerging technologies',
#  'frameworks',
#  'cloud-based ecosystems',
#  'software development capabilities',
#  'agile techniques',
#  'proven validation techniques',
#  'scripts',
#  'routines',
#  'production environments',
#  'Angular',
#  'Vue',
#  '.. APIs',
#  'emerging frameworks',
#  'architectural patterns',
#  'Node',
#  'Typescript',
#  'industry leading cloud providers',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Operational efficiencies',
#  'modern ecosystems',
#  'automated build deployment pipelines',
#  'Collaborative build practices',
#  'collaborative product engineering team',
#  'velocity multiplier',
#  'refinement',
#  'entire software stack',
#  'API',
#  'UI components',
#  'norms',
#  'software development capabilities',
#  'agile techniques',
#  'oversight',
#  'project roadmap',
#  'emerging technologies',
#  'frameworks',
#  'cloud-based ecosystems',
#  'proven validation techniques',
#  'scripts',
#  'routines',
#  'production environments',
#  'Automated analysis',
#  'UI',
#  'Data annotation',
#  'robust code',
#  'biotechnology',
#  'Python',
#  'cloud computing',
#  'automated analysis',
#  'annotation',
#  'advanced display data manipulation',
#  'strong Python coding skills',
#  'great back catalogue',
#  'homebrew projects',
#  'documentation',
#  'sleeves',
#  'Degree qualification',
#  'Python',
#  'Ideally exposure',
#  'genomic file formats',
#  'product enhancements',
#  'Workplace Search',
#  'Elasticsearch',
#  'Kibana',
#  'mentor',
#  'international teammates',
#  'mostly text-based , asynchronous , remote-first team environment',
#  'yearly conferences',
#  'constructive feedback',
#  'team ’ overall technical strategy',
#  'product roadmap',
#  'technical deliverables',
#  'important communicative part',
#  'engaged spirited team',
#  'support escalations tickets',
#  'workarounds',
#  'promptly follow-up',
#  'DevOPS',
#  'Self-starter',
#  'high-pressure , fast-paced , fast growth environment',
#  'knowledge base entries',
#  'Support Portal',
#  'SLA',
#  'timely manner',
#  'Strong TCP/IP knowledge',
#  'Proxies',
#  'NG Firewalls',
#  'SSL/IPSec',
#  'VPN',
#  'SSO',
#  'Familiarity',
#  'DLP Encryption gateways',
#  'Demonstrable experience',
#  'configuration',
#  'UNIX/Linux',
#  'Windows\xad based systems',
#  'prior Active Directory/LDAP experience',
#  'various scenarios',
#  'tcpdump',
#  'protocols',
#  '( TCP/IP',
#  'DNS',
#  'DHCP',
#  'Familiarity',
#  'Strong empathy',
#  'Interpersonal Skills',
#  'Zendesk',
#  'support portal tools',
#  'Bachelors Masters degree',
#  'support escalations tickets',
#  'workarounds',
#  'promptly follow-up',
#  'DevOPS',
#  'Self-starter',
#  'high-pressure , fast-paced , fast growth environment',
#  'knowledge base entries',
#  'Support Portal',
#  'SLA',
#  'timely manner',
#  'Strong TCP/IP knowledge',
#  'Proxies',
#  'NG Firewalls',
#  'SSL/IPSec',
#  'VPN',
#  'SSO',
#  'Familiarity',
#  'DLP Encryption gateways',
#  'Demonstrable experience',
#  'configuration',
#  'UNIX/Linux',
#  'Windows\xad based systems',
#  'prior Active Directory/LDAP experience',
#  'various scenarios',
#  'tcpdump',
#  'protocols',
#  '( TCP/IP',
#  'DNS',
#  'DHCP',
#  'Familiarity',
#  'Strong empathy',
#  'Interpersonal Skills',
#  'Zendesk',
#  'support portal tools',
#  'Bachelors Masters degree',
#  'billions',
#  'Excellent grasp',
#  'Python',
#  'advanced SQL',
#  'MLOps processes',
#  'tooling',
#  'production debugging complex systems',
#  'mathematical concepts',
#  'sklearn',
#  'SparkML',
#  'pandas',
#  'NumPy',
#  'similar packages',
#  'deep learning packages',
#  'Tensorflow',
#  'PyTorch',
#  'Keras',
#  'Spark',
#  'Elasticsearch',
#  'Kubernetes',
#  'Familiarity',
#  'AWS',
#  'automation technologies',
#  'e.g. , Kubernetes',
#  'Jenkins',
#  'GNN',
#  'RL',
#  'Recommender Systems',
#  'NLP techniques',
#  'embeddings',
#  'attention mechanisms',
#  'Familiarity',
#  'information/cyber security domain',
#  'underlying mathematical models',
#  'exploratory data analysis',
#  'algorithms',
#  'synthetic data sets',
#  'statistical machine learning models',
#  'efficacy',
#  'Analyzes',
#  'debugs',
#  'software enhancements',
#  'local , networked , Internet-related computer programs',
#  'debugging',
#  'documentation',
#  'necessary modifications',
#  'reviews product/project deliverables',
#  'life cycle methodologies',
#  'i.e. , impact assessments',
#  'external & internal specifications',
#  'manuals',
#  'QA test plans',
#  'scripts',
#  'ACI Code',
#  'troubleshooting',
#  'Bachelor ’ degree',
#  '6 8 years professional Java development experience',
#  'SDLC',
#  'Agile',
#  'following development languages / frameworks / tools',
#  'Micro-services architecture',
#  'containers',
#  'orchestration tools',
#  'e.g . Azure',
#  'docker',
#  'Kubernetes',
#  'OpenShift',
#  'K8 cluster',
#  'micro-services deployment',
#  'frameworks/tools',
#  'Nginx/Ingres',
#  'API Gateway',
#  'Service Mesh',
#  '( e.g . Istio',
#  'sensitive data encryption',
#  'e.g . HashiCorp/HSM integration',
#  'following code versioning',
#  'i.e . Git',
#  'TortoiseGit / Sourcetree',
#  'BitBucket',
#  'JIRA',
#  'testing frameworks',
#  'i.e . Junit',
#  'Mockito',
#  'Application Servers',
#  'JBoss',
#  'WebSphere',
#  'Tomcat',
#  'Database Servers',
#  'PostgreSQL',
#  'Oracle',
#  'MSSQL',
#  'Linux',
#  'Object Oriented Programming knowledge',
#  'shell scripting',
#  'JAXB',
#  'Apache Commons',
#  'Apache POI',
#  'Eclipse / STS',
#  'XML',
#  'XSD',
#  'Apache Ant',
#  'Linux bash scripting',
#  'SQL',
#  'DDL',
#  'DML',
#  'JDBC',
#  'liquibase',
#  'Java Message Service',
#  'JMS',
#  'preferred technology stack',
#  '( Primarily Elixir/Phoenix',
#  'LiveView',
#  'Ruby',
#  'Rails',
#  'modern JavaScript',
#  'amazing GraphQL',
#  'RESTful APIs',
#  'backend service teams',
#  'modern JavaScript technologies',
#  'collaborative agile/scrum environment',
#  'strong competencies',
#  'algorithms',
#  'software craftsmanship',
#  'API development',
#  'Ruby',
#  'Rails',
#  'Sinatra',
#  'Django',
#  'Node',
#  'Git',
#  ...]

# %% [markdown]
# ## 2. Replacing several irrelevant puntuations

# %%
for i in range(len(sent)):
    sent[i]=sent[i].replace('.','').replace('e.g','').\
                    replace(':','').replace('- ','-').\
                    replace('( ','(').replace(' )',')').\
                    replace('  ',' ').replace(', ',',').replace('Etc','').\
                    replace(' ,',',').replace(' /','/').replace('etc.','').\
                    replace('/ ','/').replace('eg ','').\
                    replace('ie ','').replace(' i.e','').replace('Eg',' ').replace('Ie','').strip().strip("""'(,.\-"'""")

# %%
#making first word of each data point capital
for i in range(len(data)):
    st=sent[i]
    if st!='':
        st = st.replace(st[0],st[0].upper(),1)
        sent[i]=st

# %%
sent
# Out:
# ['Ifs',
#  'Seniority',
#  'Familiarity',
#  'Functionalities',
#  'Lambdas',
#  'Java Streams',
#  'Object Oriented analysis',
#  'Relational Databases',
#  'SQL',
#  'ORM',
#  'JPA2',
#  'Hibernate',
#  'MyBatis',
#  'Hibernate',
#  'Code versioning tools',
#  'Git Familiarity',
#  'Maven',
#  'Gradle Familiarity',
#  'Continuous integration',
#  'Continuous delivery development processes',
#  'Jenkins',
#  'Bamboo',
#  'Familiarity',
#  'Frameworks',
#  'Transformations',
#  'Analytical reporting',
#  'Conceptual data models',
#  'Standard naming conventions',
#  'Coding practices',
#  'Consistency',
#  'Optimized solutions',
#  'Methodologies',
#  'High throughput data access services',
#  'Analyze/profile data',
#  'Conceptual,logical & physical data model designs',
#  'Reporting analytics solutions',
#  'Physical databases',
#  'Variances',
#  'Discrepancies',
#  'Phases',
#  'Integrations',
#  'Demonstrable experience',
#  'Logical physical data models',
#  'Interpersonal skills',
#  'Modern enterprise data architectures',
#  'Data toolsets',
#  'Data warehouse',
#  'Data marts',
#  'Modeling tools',
#  'Profiling tools',
#  'Bachelor Master degree',
#  'STEM majors',
#  'Strong algorithms',
#  'Coding background',
#  'Either Java',
#  'Python',
#  'Scala programming experience',
#  'Exceptional proficiency',
#  'SQL',
#  'Following distributed technologies',
#  'Relational Stores',
#  'Postgres',
#  'MySQL',
#  'Oracle',
#  'NoSQL Stores',
#  'Big Query',
#  'Clickhouse',
#  'Distributed Processing Engines',
#  'Apache Spark',
#  'Apache Flink',
#  'Celery',
#  'Distributed Queues',
#  'Apache Kafka',
#  'AWS Kinesis',
#  'GCP PusSub',
#  'Standard methodologies',
#  'GCP',
#  'Azure',
#  'AWS',
#  'Similar cloud platform technologies',
#  'Persuasion',
#  'Experience building cloud environments',
#  'Excellent Unix/Linux experience programming experience',
#  'Scripting',
#  'Python,shell',
#  'IPC mechanisms',
#  'TCP/IP',
#  'Kafka',
#  'Zmq',
#  'Grpc',
#  'Microservice architecture',
#  'Orchestration',
#  'Docker',
#  'Kubernetes',
#  'Cloud environments',
#  'Etcd',
#  'Service meshes',
#  'Envoy',
#  'Vault',
#  'API gateways',
#  'Load balancers',
#  'Databases',
#  'Consistency',
#  'Sql/nosql',
#  'Columnar databases',
#  'Distributed consensus',
#  'CAP Theorem',
#  'RAFT',
#  'Map-reduce,reliable multicast',
#  'Paxos',
#  'CI/CD',
#  'Github',
#  'Makefiles',
#  'Microservices',
#  'AWS',
#  'GCPNodejs',
#  'REST APIs servicesExperience writing tools',
#  'Ruby',
#  'PerlExperience',
#  'Bazel',
#  'ToolingScala programming experienceKnowledge',
#  'HTTP 2/websocket',
#  'Binary protocolsExperience',
#  'Redis',
#  'Experience building cloud environments',
#  'Excellent Unix/Linux experience programming experience',
#  'Scripting',
#  'Python,shell',
#  'IPC mechanisms',
#  'TCP/IP',
#  'Kafka',
#  'Zmq',
#  'Grpc',
#  'Microservice architecture',
#  'Orchestration',
#  'Docker',
#  'Kubernetes',
#  'Cloud environments',
#  'Etcd',
#  'Service meshes',
#  'Envoy',
#  'Vault',
#  'API gateways',
#  'Load balancers',
#  'Databases',
#  'Consistency',
#  'Sql/nosql',
#  'Columnar databases',
#  'Distributed consensus',
#  'CAP Theorem',
#  'RAFT',
#  'Map-reduce,reliable multicast',
#  'Paxos',
#  'CI/CD',
#  'Github',
#  'Makefiles',
#  'Microservices',
#  'AWS',
#  'GCPNodejs',
#  'REST APIs servicesExperience writing tools',
#  'Ruby',
#  'PerlExperience',
#  'Bazel',
#  'ToolingScala programming experienceKnowledge',
#  'HTTP 2/websocket',
#  'Binary protocolsExperience',
#  'Redis',
#  'Web UIExperience',
#  'JavaScript',
#  'HTML',
#  'CSS',
#  'Algorithms',
#  'Standard (W3C) Web UI APIs',
#  'Following types frameworks/libraries/languages',
#  'Angular',
#  'Meteor',
#  'Ember',
#  'Knockout',
#  'UI Component libraries',
#  'Vue',
#  'Bootstrap',
#  'ES6',
#  'TypeScript',
#  'Dependency injection patterns',
#  'Async Module Definition',
#  'AMD,requireJS',
#  'CommonJS',
#  'Stylesheet languages',
#  'SASS',
#  'Redux',
#  'Reactive Programming',
#  'RxJS',
#  'JavaStrong programming skills',
#  'Lambdas',
#  'Optionals',
#  'Guice knowledge',
#  'Protobuf knowledge',
#  'Familiarity',
#  'Consuming service oriented architecture layers',
#  'APIs',
#  'Highly scalable applications',
#  'Web UI Deep understanding',
#  'JSON',
#  'JavaScript Design',
#  'Architectural Patterns',
#  'Proficiency',
#  'Maven',
#  'Eclipse/NetBeans/IntelliJ',
#  'Spring/Guice',
#  'JPA/Hibernate',
#  'JavaExperience',
#  'Highly distributed scalable systems',
#  'Containers knowledge',
#  'Multi-threaded concepts',
#  'Latency',
#  'Heap',
#  'Profiling',
#  'Distributed troubleshooting',
#  'NoSQL',
#  'MongoDB',
#  'Cassandra',
#  'Redis',
#  'Java Application Servers',
#  'Oracle WebLogic',
#  'JBoss',
#  'Tomcat',
#  'Frameworks',
#  'Jasmine',
#  'Karma',
#  'Protractor',
#  'Junit',
#  'Cross-browser techniques',
#  'Chrome Dev Tools',
#  'Responsive design implementation',
#  'Browser performance auditing',
#  'Tuning',
#  'Distributed code repositories',
#  'Git,Perforce',
#  'Scrum/Kanban',
#  'Guice',
#  'GRPC',
#  '',
#  '',
#  '/BTech/BS',
#  'Excellent analytical problem-solving skills',
#  'Proven-deep-expertise',
#  'Python programming',
#  'Python',
#  'Frameworks',
#  'Django',
#  'Flask',
#  'APIs',
#  'RDBMS strong SQL knowledge',
#  'Unix/Linux command line',
#  'Object-oriented concepts',
#  'Familiarity',
#  'UI frameworks',
#  'Redux',
#  'Usability design',
#  'Hadoop/Hive/Presto',
#  'ML/AI frameworks',
#  'TensorFlow',
#  'H20',
#  'NoSQL databases',
#  'Docker container platforms',
#  'Mesos',
#  'Kubernetes',
#  'Application benchmarking',
#  'Optimization',
#  'Building user interface applications',
#  'Analytical devices',
#  'Measurement control algorithms',
#  'UI Applications',
#  'Analytical,medical,automotive devices',
#  'Proficiency',
#  'Programming user interfaces',
#  'Qt Framework',
#  'QML',
#  'Qt/C++',
#  'Regulated markets',
#  'Embedded Linux-Systems',
#  'RasPi',
#  'BeagleBone',
#  'SQL',
#  'IP-based network protocols',
#  'Linux-Yocto distribution',
#  'Myntra ’ new product platforms',
#  'Mentor',
#  'Architects',
#  'DevOps engineers',
#  'Architectural design best practices',
#  'Deployment',
#  'Scaling',
#  'Availability characteristics',
#  'Long-term architectural direction',
#  'Platforms/reusable components',
#  'Nimble delivery process',
#  'Reliability',
#  'Extensibility',
#  'Deliverables',
#  'Next generation extensible web',
#  'Mobile fashion commerce platforms',
#  'Security protocols',
#  'Customisation',
#  'Continuous scaling',
#  'Internationalization',
#  'Extensions',
#  'Architectural governance',
#  'Directional paths',
#  'New technology stacks',
#  'Multiple technology domains',
#  'Myntra',
#  'External technical forums',
#  'Business stakeholders',
#  '',
#  'Term,long-term roadmaps',
#  'Excellent abstraction',
#  'Coding',
#  'Startup/e-commerce ecosystem',
#  'High growth & matrix environment',
#  'Efficient proficient problem-solver',
#  'Business technical perspectives',
#  'Workable solutions',
#  'Leading product development end-end (portfolio',
#  '',
#  'Architectures',
#  'Multi-million sessions/transactions',
#  'Rdbms & NoSQL stores',
#  'Massively large scale distributed internet systems',
#  'Java/GO',
#  'Multi-threading performance oriented programming',
#  'Highly scalable products',
#  'Reliability',
#  'Queues',
#  'Frameworks',
#  'Object-oriented programming',
#  'Concurrency',
#  'Fundamentals',
#  'Developing user-facing web applications',
#  'Reusable,modular code',
#  'Bachelor',
#  'Backend services',
#  'React JS',
#  'JS/TypeScript',
#  'Redux',
#  'Webpack bundling',
#  'Dev tools',
#  'Markup languages',
#  'HTML5',
#  'CSS3',
#  'CSS',
#  'Pre-processing platforms',
#  'SASS',
#  'SCSS',
#  'Mysql',
#  'Postgres',
#  'Data modeling skills',
#  'Testing frameworks',
#  'Code versioning tool -Git',
#  'Phases',
#  'Deployment',
#  'Standardized methodology',
#  'Detail Design phases',
#  'Outputs',
#  'Architectural development',
#  'Modifications',
#  'Specifications',
#  'Congruence',
#  'Compatibility',
#  'Interdependent technologies',
#  'Computing related technology programs',
#  'Minimum 1 year Java design development experience',
#  'Spring Hibernate based solutions',
#  'Technical expertise',
#  'Statistical programming tasks',
#  'Technical expertise',
#  'Statistical Programming department',
#  'High-Quality Deliverables',
#  'Complex assigned tasks',
#  'Appropriate validation requirements',
#  'SOPs',
#  'Checks programming logs',
#  'Cleanliness',
#  'Inputs',
#  'Programming specifications datasets',
#  'Datasets',
#  'Handles',
#  'Dataset derivations',
#  'Programs TLFs',
#  'Biostatistical tools',
#  'Questions specification',
#  'Consistency',
#  'Lead programmer',
#  'Biostatistical Team Lead',
#  'Supervisor',
#  'Project specific macros',
#  'SOPs',
#  'Timely progress updates',
#  'EAC',
#  'Documents timelines',
#  'BIOSETUP',
#  'Integrated databases',
#  'Project macros',
#  'SAP',
#  'Shells',
#  'Programming specifications',
#  'Safety outputs',
#  'Shares accountability',
#  'Contract budget assumptions',
#  'Rework',
#  'Mentors junior staff',
#  'QC) review',
#  'Define xmls',
#  'ADaM reviewers guide',
#  'SDRG',
#  'ADRG',
#  'Lead programmer role',
#  'Proactive approach',
#  'Efficiencies',
#  'Protocols',
#  'RFPs',
#  'Bid defenses',
#  'Operational topics',
#  "Master 's Degree Computer science",
#  "Bachelor 's Degree Computer science",
#  'CDISC/ADaM/SDTM',
#  'Base SAS',
#  'SAS/STAT',
#  'SAS Macro Language',
#  'Good organizational,interpersonal,leadership communication skills',
#  'Coworkers',
#  'Talented,enthusiastic,detail-oriented Data Engineer',
#  'Agile way',
#  'Analysis data modeling',
#  'Deployment',
#  'Big data pipelines',
#  'Data Analytics team',
#  'Coda',
#  'Data pipelines',
#  'Analytical techniques',
#  'Insights',
#  'ETL',
#  'Big data pipelines',
#  'AWS technologies',
#  'Redshift',
#  'S3',
#  'EMR',
#  'EC2',
#  'DynamoDB',
#  'Kinesis Firehose',
#  'Lambda',
#  'ML teams',
#  'New behavioural events',
#  'Pipelines',
#  'Datasets',
#  'Offline analytics capabilities',
#  'Tableau',
#  'Real time dash boarding capabilities',
#  'Bachelor ’ degree',
#  'Similar quantitative field',
#  'Redshift',
#  'Another columnar store DW',
#  'Cloud solutions/AWS/Azure/Google cloud',
#  'Data visualization',
#  'Hadoop/MapReduce/AWS',
#  'EMR',
#  'Spark/Scala/PySpark/Apache Kafka/Kinesis Streams/AWS Glue',
#  'Reporting/analytics platforms',
#  'Experience building flexible data APIs',
#  'Business Preferred Qualifications',
#  'Data/software developer/scientist',
#  'Predictive analytics/decision models',
#  'Data mining libraries',
#  'Algorithm design',
#  'Problem solving',
#  'Agile Development',
#  'Collaborative Filtering',
#  'IOS mobile application',
#  'High visibility',
#  'Fundamentals',
#  'Algorithms',
#  'Relevant SWE experience',
#  'IOS apps',
#  'Preferably,apps',
#  'AppStore',
#  'XCode Experience',
#  'MVVM',
#  'Proficiency',
#  'Multi-threading performance & memory optimization',
#  'RESTful APIs',
#  'Proficient understanding',
#  'Code versioning tools',
#  'Git',
#  'Individual projects priorities',
#  'Deadlines',
#  'Deliverables',
#  'Technical expertise',
#  'Bottlenecks',
#  'Software stack',
#  'Rubrik Software Engineers',
#  'Self-starters',
#  'Limitless drive',
#  'Bachelor',
#  'Master ’ degree',
#  'Proficiency',
#  'Scala',
#  'Python',
#  'Google Cloud Platform/AWS/Azure',
#  'Unix/Linux environments',
#  'Windows environments',
#  'Networking',
#  'Hypervisors',
#  'Databases',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Databases',
#  'AWS',
#  'Granular file recovery',
#  'Kubernetes Service',
#  'AWS',
#  'Elastic compute',
#  'Technical specifications',
#  'Concise effective manner',
#  'Agile activities',
#  'Sprint planning',
#  'Thorough knowledge',
#  'Key architectural decisions',
#  'Design considerations',
#  'Detailed RCA',
#  'Bachelor',
#  'Master ’ degree',
#  'Object-oriented languages',
#  'Developing Microservices',
#  'RESTful services',
#  'SOA development experience',
#  'Preferably AWS',
#  'ORM',
#  'Entity Framework',
#  'Nhibernate',
#  'Strong TDD approach',
#  'Nunit',
#  'XUnit',
#  'Frameworks',
#  'OOP SOLID design principles',
#  'Public cloud providers',
#  'Azure',
#  'Modern java script frameworks',
#  'Highly efficient data persistent design techniques',
#  'Data retrieval performance',
#  'Queries',
#  'Designs/queries',
#  'Proficient experience',
#  'Relational databases',
#  'Microsoft SQL Server/Postgres',
#  'Non-relational DBs',
#  'MongoDB',
#  'Concurrency',
#  'Parallel work streams',
#  'Agile practices',
#  'Debugging/Troubleshooting functional technical issues',
#  'Performance/Optimization techniques',
#  'Proactively codes',
#  'Excellent analytical,quantitative,problem-solving abilities',
#  'Algorithms',
#  'Minimal oversight',
#  'Multiple concurrent priorities',
#  'Fast-paced environment',
#  'Strong interpersonal',
#  'Utilizes knowledge',
#  'Xamarin',
#  'Transforms business requirements',
#  'Technical specifications',
#  'DevOps model',
#  'Debug',
#  'Generating testing test cases',
#  'Uniformity',
#  'Architects',
#  'Various prototypes',
#  'Bachelor ’ degree',
#  'LINQ',
#  'Rest APIs',
#  'Xamarin Forms',
#  'Xamarin Native development',
#  'Xamarin iOS,Xamarin Droid',
#  'Xamarin Studio',
#  'Xamarin',
#  'Apple iOS Android platforms',
#  'Xamarin Apps',
#  'UWP',
#  'XAML',
#  'Azure integrations',
#  'Azure Active Directory',
#  'Notifications',
#  'HockeyApp/Visual Studio App Center',
#  'Continuous Integration',
#  'CI',
#  'DevOps',
#  'Automation Testing',
#  'Xamarin',
#  'Xamarin Profiler',
#  'Various code repositories',
#  'Git',
#  'TFS',
#  'MVVM Architecture',
#  'Agile methodology',
#  'VSTS',
#  'Overall Cross Platform app development ecosystem',
#  'Lifecycle',
#  'Roadmaps',
#  'Portable Class Library',
#  'PCL',
#  'SQLite',
#  'Cross-platform UX design',
#  'Xamarin Binding',
#  'SAP HANA REST API Integration',
#  'Xamarin',
#  'Xamarin Forms',
#  'Core Java',
#  'Swift/XCode',
#  'Fast-paced & complex environment',
#  'Self-motivated work ethic',
#  'Urgency',
#  'Willingness',
#  'Relevant SOPs',
#  'ServicesIntegrate Highspot',
#  'External APIs',
#  'CRM',
#  'CMS',
#  'Clean,reusable,supportable,well-tested RESTful APIs',
#  'Highspot ’ external API',
#  'Highspot ’ Salesforce integrations',
#  'Functionality',
#  '',
#  'UX',
#  'Maintainable testable code',
#  'Internal external technical documentation',
#  'Proficiency',
#  'APIs',
#  'Data formats',
#  'Data transformations',
#  'Scalable internet software',
#  'Object-oriented functional design patterns',
#  'Highspot ’ Infrastructure Platform crew',
#  'Feature crews',
#  'DevOps',
#  'Frameworks',
#  'Highspot',
#  'Highly-scalable reliable infrastructure',
#  'Engineering crews',
#  'Highly-availability distributed services',
#  'Observability',
#  'Shared frameworks',
#  'Caches',
#  'Indexes',
#  'Frameworks',
#  '',
#  'Highspot ’ feature engineering crews',
#  'Well DevOps/Site-Reliability',
#  'Maintainable testable code',
#  'Internal external technical documentation',
#  'Proficiency',
#  'Cloud computing',
#  'Containerization',
#  'Kubernetes',
#  'Scalable internet software',
#  'Object-oriented functional design patterns',
#  'Clojure',
#  'Angular',
#  'Vue',
#  'APIs',
#  'Emerging frameworks',
#  'Architectural patterns',
#  'Node',
#  'Typescript',
#  'Industry leading cloud providers',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Operational efficiencies',
#  'Modern ecosystems',
#  'Automated build deployment pipelines',
#  'Collaborative build practices',
#  'Collaborative product engineering team',
#  'Velocity multiplier',
#  'Refinement',
#  'Entire software stack',
#  'API',
#  'UI components',
#  'Norms',
#  'Software development capabilities',
#  'Agile techniques',
#  'Oversight',
#  'Project roadmap',
#  'Emerging technologies',
#  'Frameworks',
#  'Cloud-based ecosystems',
#  'Proven validation techniques',
#  'Scripts',
#  'Routines',
#  'Production environments',
#  'Angular',
#  'Vue',
#  'APIs',
#  'Emerging frameworks',
#  'Architectural patterns',
#  'Node',
#  'Typescript',
#  'Industry leading cloud providers',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Operational efficiencies',
#  'Modern ecosystems',
#  'Automated build deployment pipelines',
#  'Collaborative build practices',
#  'Collaborative product engineering team',
#  'Refinement',
#  'Talented software engineers',
#  'Architects',
#  'Entire software stack',
#  'API',
#  'UI components',
#  'Norms',
#  'Emerging technologies',
#  'Frameworks',
#  'Cloud-based ecosystems',
#  'Software development capabilities',
#  'Agile techniques',
#  'Proven validation techniques',
#  'Scripts',
#  'Routines',
#  'Production environments',
#  'Angular',
#  'Vue',
#  'APIs',
#  'Emerging frameworks',
#  'Architectural patterns',
#  'Node',
#  'Typescript',
#  'Industry leading cloud providers',
#  'AWS',
#  'Azure',
#  'GCP',
#  'Operational efficiencies',
#  'Modern ecosystems',
#  'Automated build deployment pipelines',
#  'Collaborative build practices',
#  'Collaborative product engineering team',
#  'Velocity multiplier',
#  'Refinement',
#  'Entire software stack',
#  'API',
#  'UI components',
#  'Norms',
#  'Software development capabilities',
#  'Agile techniques',
#  'Oversight',
#  'Project roadmap',
#  'Emerging technologies',
#  'Frameworks',
#  'Cloud-based ecosystems',
#  'Proven validation techniques',
#  'Scripts',
#  'Routines',
#  'Production environments',
#  'Automated analysis',
#  'UI',
#  'Data annotation',
#  'Robust code',
#  'Biotechnology',
#  'Python',
#  'Cloud computing',
#  'Automated analysis',
#  'Annotation',
#  'Advanced display data manipulation',
#  'Strong Python coding skills',
#  'Great back catalogue',
#  'Homebrew projects',
#  'Documentation',
#  'Sleeves',
#  'Degree qualification',
#  'Python',
#  'Ideally exposure',
#  'Genomic file formats',
#  'Product enhancements',
#  'Workplace Search',
#  'Elasticsearch',
#  'Kibana',
#  'Mentor',
#  'International teammates',
#  'Mostly text-based,asynchronous,remote-first team environment',
#  'Yearly conferences',
#  'Constructive feedback',
#  'Team ’ overall technical strategy',
#  'Product roadmap',
#  'Technical deliverables',
#  'Important communicative part',
#  'Engaged spirited team',
#  'Support escalations tickets',
#  'Workarounds',
#  'Promptly follow-up',
#  'DevOPS',
#  'Self-starter',
#  'High-pressure,fast-paced,fast growth environment',
#  'Knowledge base entries',
#  'Support Portal',
#  'SLA',
#  'Timely manner',
#  'Strong TCP/IP knowledge',
#  'Proxies',
#  'NG Firewalls',
#  'SSL/IPSec',
#  'VPN',
#  'SSO',
#  'Familiarity',
#  'DLP Encryption gateways',
#  'Demonstrable experience',
#  'Configuration',
#  'UNIX/Linux',
#  'Windows\xad based systems',
#  'Prior Active Directory/LDAP experience',
#  'Various scenarios',
#  'Tcpdump',
#  'Protocols',
#  'TCP/IP',
#  'DNS',
#  'DHCP',
#  'Familiarity',
#  'Strong empathy',
#  'Interpersonal Skills',
#  'Zendesk',
#  'Support portal tools',
#  'Bachelors Masters degree',
#  'Support escalations tickets',
#  'Workarounds',
#  'Promptly follow-up',
#  'DevOPS',
#  'Self-starter',
#  'High-pressure,fast-paced,fast growth environment',
#  'Knowledge base entries',
#  'Support Portal',
#  'SLA',
#  'Timely manner',
#  'Strong TCP/IP knowledge',
#  'Proxies',
#  'NG Firewalls',
#  'SSL/IPSec',
#  'VPN',
#  'SSO',
#  'Familiarity',
#  'DLP Encryption gateways',
#  'Demonstrable experience',
#  'Configuration',
#  'UNIX/Linux',
#  'Windows\xad based systems',
#  'Prior Active Directory/LDAP experience',
#  'Various scenarios',
#  'Tcpdump',
#  'Protocols',
#  'TCP/IP',
#  'DNS',
#  'DHCP',
#  'Familiarity',
#  'Strong empathy',
#  'Interpersonal Skills',
#  'Zendesk',
#  'Support portal tools',
#  'Bachelors Masters degree',
#  'Billions',
#  'Excellent grasp',
#  'Python',
#  'Advanced SQL',
#  'MLOps processes',
#  'Tooling',
#  'Production debugging complex systems',
#  'Mathematical concepts',
#  'Sklearn',
#  'SparkML',
#  'Pandas',
#  'NumPy',
#  'Similar packages',
#  'Deep learning packages',
#  'Tensorflow',
#  'PyTorch',
#  'Keras',
#  'Spark',
#  'Elasticsearch',
#  'Kubernetes',
#  'Familiarity',
#  'AWS',
#  'Automation technologies',
#  'Eg,Kubernetes',
#  'Jenkins',
#  'GNN',
#  'RL',
#  'Recommender Systems',
#  'NLP techniques',
#  'Embeddings',
#  'Attention mechanisms',
#  'Familiarity',
#  'Information/cyber security domain',
#  'Underlying mathematical models',
#  'Exploratory data analysis',
#  'Algorithms',
#  'Synthetic data sets',
#  'Statistical machine learning models',
#  'Efficacy',
#  'Analyzes',
#  'Debugs',
#  'Software enhancements',
#  'Local,networked,Internet-related computer programs',
#  'Debugging',
#  'Documentation',
#  'Necessary modifications',
#  'Reviews product/project deliverables',
#  'Life cycle methodologies',
#  'Ie,impact assessments',
#  'External & internal specifications',
#  'Manuals',
#  'QA test plans',
#  'Scripts',
#  'ACI Code',
#  'Troubleshooting',
#  'Bachelor ’ degree',
#  '6 8 years professional Java development experience',
#  'SDLC',
#  'Agile',
#  'Following development languages/frameworks/tools',
#  'Micro-services architecture',
#  'Containers',
#  'Orchestration tools',
#  'Azure',
#  'Docker',
#  'Kubernetes',
#  'OpenShift',
#  'K8 cluster',
#  'Micro-services deployment',
#  'Frameworks/tools',
#  'Nginx/Ingres',
#  'API Gateway',
#  'Service Mesh',
#  'Istio',
#  'Sensitive data encryption',
#  'HashiCorp/HSM integration',
#  'Following code versioning',
#  'Git',
#  'TortoiseGit/Sourcetree',
#  'BitBucket',
#  'JIRA',
#  'Testing frameworks',
#  'Junit',
#  'Mockito',
#  'Application Servers',
#  'JBoss',
#  'WebSphere',
#  'Tomcat',
#  'Database Servers',
#  'PostgreSQL',
#  'Oracle',
#  'MSSQL',
#  'Linux',
#  'Object Oriented Programming knowledge',
#  'Shell scripting',
#  'JAXB',
#  'Apache Commons',
#  'Apache POI',
#  'Eclipse/STS',
#  'XML',
#  'XSD',
#  'Apache Ant',
#  'Linux bash scripting',
#  'SQL',
#  'DDL',
#  'DML',
#  'JDBC',
#  'Liquibase',
#  'Java Message Service',
#  'JMS',
#  'Preferred technology stack',
#  'Primarily Elixir/Phoenix',
#  'LiveView',
#  'Ruby',
#  'Rails',
#  'Modern JavaScript',
#  'Amazing GraphQL',
#  'RESTful APIs',
#  'Backend service teams',
#  'Modern JavaScript technologies',
#  'Collaborative agile/scrum environment',
#  'Strong competencies',
#  'Algorithms',
#  'Software craftsmanship',
#  'API development',
#  'Ruby',
#  'Rails',
#  'Sinatra',
#  'Django',
#  'Node',
#  'Git',
#  ...]

# %% [markdown]
# ## 3. Creating dataframe for result

# %%
df = pd.DataFrame(sent,columns=['Technology Skills'])

# %%
df
# Out:
#                               Technology Skills
# 0                                           Ifs
# 1                                     Seniority
# 2                                   Familiarity
# 3                               Functionalities
# 4                                       Lambdas
# ...                                         ...
# 34111                               Negotiation
# 34112                                 Deadlines
# 34113  Self-motivated,enthusiastic strong drive
# 34114                               Negotiation
# 34115                                 Deadlines
#
# [34116 rows x 1 columns]

# %%
df.value_counts()
# Out:
# Technology Skills
# Python                              318
# AWS                                 256
# JavaScript                          221
# Familiarity                         221
# Kubernetes                          196
#                                    ...
# Firmware functionality                1
# Firmware operation                    1
# Firmware software requirements        1
# Firmware/software QA Development      1
# 🏗                                     1
# Length: 14502, dtype: int64

# %%
df.value_counts()[df.value_counts()>10]
# Out:
# Technology Skills
# Python                                     318
# AWS                                        256
# JavaScript                                 221
# Familiarity                                221
# Kubernetes                                 196
#                                           ...
# Backend software engineering experience     11
# Better scalability                          11
# Quality assurance                           11
# Automated deployment pipelines              11
# Threat modeling                             11
# Length: 453, dtype: int64

# %%
#making list of some irrelevant datapoint
words_to_delete=['Familiarity','Visibility','Team mates','Observability','Deliverables','Deadlines','Documentation','Mentor','Willingness','Frameworks','Protocols','● Experience','Large dataset','Schedules','Fluency','Seniority','Negotiation','Functionalities']

# %%
#removing duplicates
df.drop_duplicates(keep='first',inplace=True)

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#                               Technology Skills
# 0                                           Ifs
# 1                                     Seniority
# 2                                   Familiarity
# 3                               Functionalities
# 4                                       Lambdas
# ...                                         ...
# 14497                           Telecom product
# 14498                      Leadership qualities
# 14499                                  Actalent
# 14500  Self-motivated,enthusiastic strong drive
# 14501                               Negotiation
#
# [14502 rows x 1 columns]

# %%
invalid_data_index=[]
for i in range(len(df)):
    if df.iloc[i].values[0] in  words_to_delete:
        invalid_data_index.append(i)

# %%
#removing irrelevant datapoint 
for i in range(len(df)):
    if len(df.iloc[i].values[0])==1 or len(df.iloc[i].values[0])==0:
        print(df.iloc[i].values[0])
        invalid_data_index.append(i)
invalid_data_index
# Out:
# #
# +
# ﻿
# Ø
# 
# ∙
# ❤
# 🏗
# [1,
#  2,
#  3,
#  21,
#  225,
#  237,
#  344,
#  410,
#  511,
#  534,
#  580,
#  1163,
#  1242,
#  1250,
#  1253,
#  1559,
#  8266,
#  14501,
#  188,
#  1103,
#  2673,
#  4544,
#  4655,
#  7929,
#  8810,
#  9219,
#  13330]

# %%
for i in invalid_data_index:
    df.drop(i,inplace=True)

# %%
df.value_counts()
# Out:
# Technology Skills
# # # ENG                                                                    1
# Perth                                                                      1
# Performant solutions                                                       1
# Performant,scalable resilient applications                                 1
# Performant,scalable,secure software                                        1
#                                                                           ..
# Enterprise Architecture roles                                              1
# Enterprise Class Financial application web portals                         1
# Enterprise Cloud computing                                                 1
# Enterprise Customer Care (ECC) Professional Services (PS) business unit    1
# ﻿Tier 1 Educational Background Preferred -IIT/NIT/DTU                      1
# Length: 14475, dtype: int64

# %%
df.reset_index(drop=True,inplace=True)

# %%
df
# Out:
#                               Technology Skills
# 0                                           Ifs
# 1                                       Lambdas
# 2                                  Java Streams
# 3                      Object Oriented analysis
# 4                          Relational Databases
# ...                                         ...
# 14470                       C/embedded software
# 14471                           Telecom product
# 14472                      Leadership qualities
# 14473                                  Actalent
# 14474  Self-motivated,enthusiastic strong drive
#
# [14475 rows x 1 columns]

# %%
df.to_csv('Cleaned_Data.csv',index=False)
